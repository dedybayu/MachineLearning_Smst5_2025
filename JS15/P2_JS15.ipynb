# %% [markdown]
# | No. Presensi | Nama               | NIM        | Kelas   |
# | ------------ | ------------------ | ---------- | ------- |
# | 08           | Dedy Bayu Setiawan | 2341720041 | TI - 3H |

# %% [markdown]
# # Praktikum 2

# %% [markdown]
# **Link**: [https://huggingface.co/spaces/dedybayu/daynight-classifier-dedybayu](https://huggingface.co/spaces/dedybayu/daynight-classifier-dedybayu)
